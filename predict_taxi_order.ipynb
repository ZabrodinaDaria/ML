# %% [markdown]
# # Забродина Дарья
# # BASELINE 2

# %%
import pandas as pd

from sklearn.preprocessing import OneHotEncoder
from lightgbm import LGBMClassifier
from sklearn.neighbors import NearestNeighbors, KNeighborsClassifier
from sklearn.metrics import roc_auc_score
import numpy as np
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import cross_val_score, cross_val_predict, StratifiedKFold

# %% [markdown]
# Считываем данные:

# %%
data_train = pd.read_csv('train_data.csv', parse_dates=['due'])
target_train = pd.read_csv('train_target.csv')
data_train['target'] = target_train
data_test = pd.read_csv('test_data.csv', parse_dates=['due'])

# %% [markdown]
# Сортируем данные по времени:

# %%
data_train.sort_values(by='due', inplace=True)

# %%
data_train.head()
# Out:
#                 dist                 due f_class        lat        lon  \
# 823150  17990.125431 2014-01-01 00:09:32  econom  55.750130  37.823242
# 685195   2322.180999 2014-01-01 00:10:00  econom  55.711488  37.884183
# 996389  14608.577392 2014-01-01 00:10:00  econom  55.633404  37.797595
# 497811  20055.569096 2014-01-01 00:10:00  econom  55.780380  37.645240
# 812346  20585.444093 2014-01-01 00:10:00  econom  55.675676  37.500387
#
#        s_class t_class  target
# 823150     NaN     NaN       1
# 685195     NaN     NaN       0
# 996389     NaN     NaN       0
# 497811     NaN     NaN       0
# 812346     NaN     NaN       1

# %%
df_train = data_train['due']
df_test = data_test['due']

# %%
data_test.shape
# Out:
# (510937, 7)

# %% [markdown]
# ## Добавление базовых признаков на основе ноутбука с безлайном 1

# %% [markdown]
# Функция по добавлению признаков:
#
# * делим время на составные части
# * обрабатываем пропущенные значения

# %%
def add_features(data_train, data_test):
    for data in [data_train, data_test]:
        data['is_dist'] = (data['dist'] == -1).astype(float)
        
        # add tmp features
        data.loc[:,'time_as_str'] = data['due'].astype(str).apply(lambda x: x[x.find(' ') + 1:-4])
        data.loc[:, 'date_as_str'] = data['due'].astype(str).apply(lambda x: x[:x.find(' ')])
        
        # add date features
        data_date_structure = pd.to_datetime(data['date_as_str'])
        data.loc[:, 'date'] =  data_date_structure 
        data.loc[:, 'week_day'] = data_date_structure.dt.dayofweek
        data.loc[:, 'weekend'] = ((data['week_day'] == 5) | (data['week_day'] == 6) ).astype(int)
        
        # add time features
        start_time = datetime.datetime(2014, 1, 1, 0, 0)
        data_tmp = pd.to_datetime(data['due'])
        data['time_as_datetime'] = data_tmp
        data.loc[:, 'time_in_seconds'] = pd.to_timedelta(data['time_as_str']).dt.total_seconds()
        data.loc[:, 'time_in_minutes'] = data['time_in_seconds'] // 60
        data.loc[:, 'time_in_hours'] = data['time_in_minutes'] // 60
        data.loc[:, 'total_minutes'] = (pd.to_timedelta(data['time_as_datetime'] - start_time).dt.total_seconds()//60).astype('float')
      
        
        # fillna for cat features
        data.fillna({
            'f_class': 'unknown_f',
            's_class': 'unknown_s',
            't_class': 'unknown_t',
        }, inplace=True)
        
        # drop tmp features
        data.drop(['time_as_str', 'date_as_str'], axis=1, inplace=True)
    
    for column in ['f_class', 's_class', 't_class', 'week_day']:
        data_train[column] = data_train[column].astype('category')
        data_test[column] = data_test[column].astype('category')
        data_test[column] = (
            data_test[column]
            .cat
            .set_categories(data_train[column].cat.categories)
        )
    
    data_train = pd.get_dummies(data_train)
    data_test = pd.get_dummies(data_test)
    
    return data_train, data_test

# %%
data_train, data_test = add_features(data_train, data_test)

# %%
data_train.head()
# Out:
#                 dist                 due        lat        lon  target  \
# 823150  17990.125431 2014-01-01 00:09:32  55.750130  37.823242       1
# 685195   2322.180999 2014-01-01 00:10:00  55.711488  37.884183       0
# 996389  14608.577392 2014-01-01 00:10:00  55.633404  37.797595       0
# 497811  20055.569096 2014-01-01 00:10:00  55.780380  37.645240       0
# 812346  20585.444093 2014-01-01 00:10:00  55.675676  37.500387       1
#
#         is_dist       date  weekend    time_as_datetime  time_in_seconds  \
# 823150      0.0 2014-01-01        0 2014-01-01 00:09:32            572.0
# 685195      0.0 2014-01-01        0 2014-01-01 00:10:00            600.0
# 996389      0.0 2014-01-01        0 2014-01-01 00:10:00            600.0
# 497811      0.0 2014-01-01        0 2014-01-01 00:10:00            600.0
# 812346      0.0 2014-01-01        0 2014-01-01 00:10:00            600.0
#
#            ...      t_class_econom  t_class_unknown_t  t_class_vip  \
# 823150     ...                   0                  1            0
# 685195     ...                   0                  1            0
# 996389     ...                   0                  1            0
# 497811     ...                   0                  1            0
# 812346     ...                   0                  1            0
#
#         week_day_0  week_day_1  week_day_2  week_day_3  week_day_4  \
# 823150           0           0           1           0           0
# 685195           0           0           1           0           0
# 996389           0           0           1           0           0
# 497811           0           0           1           0           0
# 812346           0           0           1           0           0
#
#         week_day_5  week_day_6
# 823150           0           0
# 685195           0           0
# 996389           0           0
# 497811           0           0
# 812346           0           0
#
# [5 rows x 32 columns]

# %% [markdown]
# ## City

# %% [markdown]
# Все точки можно разбить на кластеры, соответствующие пяти городам: Москве, Казани, Нижнему Новогороду, Санкт-Петербургу, Воронежу. Будем рассматривать центры этих городов как центры кластеров. Затем для каждой точки с помощью метода ближайшего соседа найдем, к какому кластеру она относилась, а также найдем расстояние до центра этого кластера.

# %%
cities = pd.DataFrame([['moscow', 55.755814, 37.617635],
                       ['kazan',  55.796289, 49.108795],
                       ['nnovgorod',  56.326797, 44.006516],
                       ['spb',  59.939095, 30.315868],
                       ['voronezh',  51.660781, 39.200269]], columns = ['city', 'lat', 'lon'] ) 

NN = NearestNeighbors(n_neighbors=1, metric='euclidean')
NN.fit(cities[['lat', 'lon']])
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='euclidean',
#          metric_params=None, n_jobs=1, n_neighbors=1, p=2, radius=1.0)

# %%
def get_city_features(X):
    dist, neighbours = NN.kneighbors(X[['lat', 'lon']])
    X['centr_dist'] = dist[:, 0]
    X['city'] = neighbours[:, 0]
    X['city_name'] = X['city'].map(cities.city)

# %%
get_city_features(data_train)
get_city_features(data_test)

# %%
data_train.head()
# Out:
#                 dist                 due        lat        lon  target  \
# 823150  17990.125431 2014-01-01 00:09:32  55.750130  37.823242       1
# 685195   2322.180999 2014-01-01 00:10:00  55.711488  37.884183       0
# 996389  14608.577392 2014-01-01 00:10:00  55.633404  37.797595       0
# 497811  20055.569096 2014-01-01 00:10:00  55.780380  37.645240       0
# 812346  20585.444093 2014-01-01 00:10:00  55.675676  37.500387       1
#
#         is_dist       date  weekend    time_as_datetime  time_in_seconds  \
# 823150      0.0 2014-01-01        0 2014-01-01 00:09:32            572.0
# 685195      0.0 2014-01-01        0 2014-01-01 00:10:00            600.0
# 996389      0.0 2014-01-01        0 2014-01-01 00:10:00            600.0
# 497811      0.0 2014-01-01        0 2014-01-01 00:10:00            600.0
# 812346      0.0 2014-01-01        0 2014-01-01 00:10:00            600.0
#
#           ...      week_day_0  week_day_1  week_day_2  week_day_3  week_day_4  \
# 823150    ...               0           0           1           0           0
# 685195    ...               0           0           1           0           0
# 996389    ...               0           0           1           0           0
# 497811    ...               0           0           1           0           0
# 812346    ...               0           0           1           0           0
#
#         week_day_5  week_day_6  centr_dist  city  city_name
# 823150           0           0    0.205686     0     moscow
# 685195           0           0    0.270208     0     moscow
# 996389           0           0    0.217646     0     moscow
# 497811           0           0    0.036953     0     moscow
# 812346           0           0    0.142018     0     moscow
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Atipic hour

# %% [markdown]
# Смотрим, как много вызовов такси было совершено в данный день и час в данном городе по отношению к среднему количеству вызовов в этот час по всем дням в этом городе.

# %%
data_train['time'] = data_train.due.dt.floor("H")
data_test['time'] = data_test.due.dt.floor("H")

# %%
def get_atipic_hour(X):
    ctc = X.groupby(['city', 'time']).due.count().rename('counts_per_hour').reset_index()
    ctc['hour'] = ctc.time.dt.hour
    ctc['mean_count'] = ctc.groupby(['city', 'hour']).counts_per_hour.transform('mean')
    ctc['atipic_hour'] = ctc.counts_per_hour/ctc.mean_count
    return pd.merge(X, ctc[['city', 'time', 'atipic_hour']], on = ['city', 'time'], how = 'left')

# %%
data_train = get_atipic_hour(data_train)
data_test = get_atipic_hour(data_test)

# %% [markdown]
# ## KNN with lat and lon

# %% [markdown]
# Воспользуемся методом ближайших соседей, чтобы для каждой точки из тестовой выборки на основе 100 ближайших соседей из тренировочной выборки найти вероятность принадлежности классу 0 или 1.

# %%
KNC = KNeighborsClassifier(metric='euclidean', n_neighbors=100)

# %%
KNC.fit(data_train[['lat', 'lon']], data_train.target)
test_prediction = KNC.predict_proba(data_test[['lat', 'lon']])
data_test['knn_prediction'] = test_prediction[:,0]

# %% [markdown]
# Для того, чтобы посмотреть результат на валидационной выборке, для тренировочных данных тоже нужно найти предсказания, что делается с помощью разбиения на фолды.

# %%
prediction  = cross_val_predict(KNC, data_train[['lat', 'lon']], data_train.target, cv=10, method='predict_proba')
data_train['knn_prediction'] = prediction[:,0]

# %% [markdown]
# ## KNN with time

# %% [markdown]
# Предыдущий KNN дал небольшой прирост результата. Возникла идея использовать при подсчете расстояния еще и время, предварительно его нормировав. Это соотносится со следующим бытовым рассуждением: часто после отмены такси человек снова делает заказ через пару минут и в относительно близкой точке. Расстояние до ближайшего соседа в таких координатах оказалось признаком, который дал большой прирост.

# %%
print(data_test['total_minutes'].max())
print(data_train['total_minutes'].max())
# Out:
# 129595.0
# 92640.0

# %%
data_train['z'] = data_train['total_minutes'] * 60 / 129595
data_test['z'] = data_test['total_minutes'] * 60 / 129595

# %%
train_shape = data_train.shape[0]

# %%
samples_train = data_train[['lat', 'lon', 'z']]
samples_test = data_test[['lat', 'lon', 'z']]
X = pd.concat([samples_train, samples_test])

# %%
neigh = NearestNeighbors(n_neighbors=1)
neigh.fit(X)
dist, neighbor = neigh.kneighbors() 
X['neighbor'] = neighbor
X['dist_t'] = dist

# %%
data_train['dist_t'] = X['dist_t'][:train_shape]
data_test['dist_t'] = X['dist_t'][train_shape:]

# %% [markdown]
# ## Features

# %% [markdown]
# Тут создаем список признаков, которые и будут использованы в модели.

# %%
feature_columns = ['dist', 'centr_dist', 'lat', 'lon',  'time_in_hours', 'weekend',  'atipic_hour', 'time_in_seconds', 'f_class_business', 'f_class_econom',
       'f_class_vip', 's_class_business', 's_class_econom',
      's_class_vip',  'dist_t', 'knn_prediction']
target_column = ['target']

# %% [markdown]
# ## Validation

# %%
train_size = int(0.7 * data_train.shape[0])
train = data_train.iloc[:train_size]
valid = data_train.iloc[train_size:]

# %%
clf = LGBMClassifier(n_estimators=1600, learning_rate=0.04, num_leaves=63, max_depth = 20)
clf.fit(
    train[feature_columns], train[target_column].values.ravel(),
    eval_set=[(valid[feature_columns], valid[target_column].values.ravel())],
    eval_metric='auc',
    verbose=True,
    early_stopping_rounds=50,
)
# Out:
# [1]	valid_0's auc: 0.716668	valid_0's binary_logloss: 0.420286
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's auc: 0.717293	valid_0's binary_logloss: 0.416537
# [3]	valid_0's auc: 0.718213	valid_0's binary_logloss: 0.413229
# [4]	valid_0's auc: 0.718695	valid_0's binary_logloss: 0.410259
# [5]	valid_0's auc: 0.719979	valid_0's binary_logloss: 0.407625
# [6]	valid_0's auc: 0.720962	valid_0's binary_logloss: 0.40524
# [7]	valid_0's auc: 0.721393	valid_0's binary_logloss: 0.403105
# [8]	valid_0's auc: 0.72234	valid_0's binary_logloss: 0.401108
# [9]	valid_0's auc: 0.722562	valid_0's binary_logloss: 0.399314
# [10]	valid_0's auc: 0.722808	valid_0's binary_logloss: 0.397674
# [11]	valid_0's auc: 0.723362	valid_0's binary_logloss: 0.396092
# [12]	valid_0's auc: 0.723814	valid_0's binary_logloss: 0.39467
# [13]	valid_0's auc: 0.72464	valid_0's binary_logloss: 0.393361
# [14]	valid_0's auc: 0.725453	valid_0's binary_logloss: 0.392115
# [15]	valid_0's auc: 0.725949	valid_0's binary_logloss: 0.391004
# [16]	valid_0's auc: 0.726197	valid_0's binary_logloss: 0.389947
# [17]	valid_0's auc: 0.727099	valid_0's binary_logloss: 0.388981
# [18]	valid_0's auc: 0.727775	valid_0's binary_logloss: 0.388041
# [19]	valid_0's auc: 0.728182	valid_0's binary_logloss: 0.387223
# [20]	valid_0's auc: 0.728643	valid_0's binary_logloss: 0.386388
# [21]	valid_0's auc: 0.728978	valid_0's binary_logloss: 0.385628
# [22]	valid_0's auc: 0.729126	valid_0's binary_logloss: 0.384924
# [23]	valid_0's auc: 0.729316	valid_0's binary_logloss: 0.384267
# [24]	valid_0's auc: 0.729515	valid_0's binary_logloss: 0.383627
# [25]	valid_0's auc: 0.729715	valid_0's binary_logloss: 0.383063
# [26]	valid_0's auc: 0.729935	valid_0's binary_logloss: 0.382478
# [27]	valid_0's auc: 0.730137	valid_0's binary_logloss: 0.381959
# [28]	valid_0's auc: 0.730372	valid_0's binary_logloss: 0.381447
# [29]	valid_0's auc: 0.730546	valid_0's binary_logloss: 0.38101
# [30]	valid_0's auc: 0.730676	valid_0's binary_logloss: 0.380546
# [31]	valid_0's auc: 0.730826	valid_0's binary_logloss: 0.380139
# [32]	valid_0's auc: 0.731042	valid_0's binary_logloss: 0.379772
# [33]	valid_0's auc: 0.731193	valid_0's binary_logloss: 0.37939
# [34]	valid_0's auc: 0.731284	valid_0's binary_logloss: 0.379068
# [35]	valid_0's auc: 0.731479	valid_0's binary_logloss: 0.378722
# [36]	valid_0's auc: 0.731613	valid_0's binary_logloss: 0.37842
# [37]	valid_0's auc: 0.731723	valid_0's binary_logloss: 0.37813
# [38]	valid_0's auc: 0.731916	valid_0's binary_logloss: 0.377851
# [39]	valid_0's auc: 0.732152	valid_0's binary_logloss: 0.377553
# [40]	valid_0's auc: 0.732254	valid_0's binary_logloss: 0.377314
# [41]	valid_0's auc: 0.732402	valid_0's binary_logloss: 0.377073
# [42]	valid_0's auc: 0.732482	valid_0's binary_logloss: 0.376817
# [43]	valid_0's auc: 0.732676	valid_0's binary_logloss: 0.376577
# [44]	valid_0's auc: 0.732797	valid_0's binary_logloss: 0.376375
# [45]	valid_0's auc: 0.732915	valid_0's binary_logloss: 0.376166
# [46]	valid_0's auc: 0.73306	valid_0's binary_logloss: 0.375978
# [47]	valid_0's auc: 0.733196	valid_0's binary_logloss: 0.375794
# [48]	valid_0's auc: 0.733293	valid_0's binary_logloss: 0.375618
# [49]	valid_0's auc: 0.733351	valid_0's binary_logloss: 0.375452
# [50]	valid_0's auc: 0.733448	valid_0's binary_logloss: 0.375308
# [51]	valid_0's auc: 0.733653	valid_0's binary_logloss: 0.375121
# [52]	valid_0's auc: 0.733765	valid_0's binary_logloss: 0.374975
# [53]	valid_0's auc: 0.733857	valid_0's binary_logloss: 0.374843
# [54]	valid_0's auc: 0.734009	valid_0's binary_logloss: 0.374693
# [55]	valid_0's auc: 0.73409	valid_0's binary_logloss: 0.374588
# [56]	valid_0's auc: 0.734203	valid_0's binary_logloss: 0.374453
# [57]	valid_0's auc: 0.734331	valid_0's binary_logloss: 0.374315
# [58]	valid_0's auc: 0.734398	valid_0's binary_logloss: 0.374212
# [59]	valid_0's auc: 0.734578	valid_0's binary_logloss: 0.374067
# [60]	valid_0's auc: 0.734691	valid_0's binary_logloss: 0.373955
# [61]	valid_0's auc: 0.734755	valid_0's binary_logloss: 0.373863
# [62]	valid_0's auc: 0.734823	valid_0's binary_logloss: 0.37377
# [63]	valid_0's auc: 0.734892	valid_0's binary_logloss: 0.37368
# [64]	valid_0's auc: 0.734969	valid_0's binary_logloss: 0.373582
# [65]	valid_0's auc: 0.735044	valid_0's binary_logloss: 0.373497
# [66]	valid_0's auc: 0.735151	valid_0's binary_logloss: 0.37339
# [67]	valid_0's auc: 0.73523	valid_0's binary_logloss: 0.3733
# [68]	valid_0's auc: 0.735321	valid_0's binary_logloss: 0.373218
# [69]	valid_0's auc: 0.735442	valid_0's binary_logloss: 0.37311
# [70]	valid_0's auc: 0.735512	valid_0's binary_logloss: 0.373032
# [71]	valid_0's auc: 0.73558	valid_0's binary_logloss: 0.372949
# [72]	valid_0's auc: 0.735612	valid_0's binary_logloss: 0.372886
# [73]	valid_0's auc: 0.73567	valid_0's binary_logloss: 0.372827
# [74]	valid_0's auc: 0.735756	valid_0's binary_logloss: 0.372757
# [75]	valid_0's auc: 0.735853	valid_0's binary_logloss: 0.372687
# [76]	valid_0's auc: 0.735931	valid_0's binary_logloss: 0.372598
# [77]	valid_0's auc: 0.735977	valid_0's binary_logloss: 0.372537
# [78]	valid_0's auc: 0.736053	valid_0's binary_logloss: 0.37247
# [79]	valid_0's auc: 0.73611	valid_0's binary_logloss: 0.372392
# [80]	valid_0's auc: 0.73615	valid_0's binary_logloss: 0.372335
# [81]	valid_0's auc: 0.736207	valid_0's binary_logloss: 0.372281
# [82]	valid_0's auc: 0.736271	valid_0's binary_logloss: 0.372226
# [83]	valid_0's auc: 0.736314	valid_0's binary_logloss: 0.37218
# [84]	valid_0's auc: 0.736415	valid_0's binary_logloss: 0.372119
# [85]	valid_0's auc: 0.736495	valid_0's binary_logloss: 0.372058
# [86]	valid_0's auc: 0.73656	valid_0's binary_logloss: 0.372009
# [87]	valid_0's auc: 0.736606	valid_0's binary_logloss: 0.371962
# [88]	valid_0's auc: 0.736667	valid_0's binary_logloss: 0.371909
# [89]	valid_0's auc: 0.73674	valid_0's binary_logloss: 0.371862
# [90]	valid_0's auc: 0.736799	valid_0's binary_logloss: 0.371811
# [91]	valid_0's auc: 0.736881	valid_0's binary_logloss: 0.371752
# [92]	valid_0's auc: 0.73694	valid_0's binary_logloss: 0.371697
# [93]	valid_0's auc: 0.736983	valid_0's binary_logloss: 0.371657
# [94]	valid_0's auc: 0.737057	valid_0's binary_logloss: 0.371613
# [95]	valid_0's auc: 0.737123	valid_0's binary_logloss: 0.37156
# [96]	valid_0's auc: 0.737163	valid_0's binary_logloss: 0.371523
# [97]	valid_0's auc: 0.737232	valid_0's binary_logloss: 0.371479
# [98]	valid_0's auc: 0.737277	valid_0's binary_logloss: 0.371437
# [99]	valid_0's auc: 0.737321	valid_0's binary_logloss: 0.371403
# [100]	valid_0's auc: 0.737366	valid_0's binary_logloss: 0.371372
# [101]	valid_0's auc: 0.737435	valid_0's binary_logloss: 0.37133
# [102]	valid_0's auc: 0.737538	valid_0's binary_logloss: 0.371278
# [103]	valid_0's auc: 0.737579	valid_0's binary_logloss: 0.371249
# [104]	valid_0's auc: 0.737599	valid_0's binary_logloss: 0.37122
# [105]	valid_0's auc: 0.737642	valid_0's binary_logloss: 0.371185
# [106]	valid_0's auc: 0.737724	valid_0's binary_logloss: 0.371144
# [107]	valid_0's auc: 0.73778	valid_0's binary_logloss: 0.371108
# [108]	valid_0's auc: 0.737822	valid_0's binary_logloss: 0.371076
# [109]	valid_0's auc: 0.737878	valid_0's binary_logloss: 0.371033
# [110]	valid_0's auc: 0.737892	valid_0's binary_logloss: 0.371012
# [111]	valid_0's auc: 0.737923	valid_0's binary_logloss: 0.370988
# [112]	valid_0's auc: 0.737994	valid_0's binary_logloss: 0.370958
# [113]	valid_0's auc: 0.738035	valid_0's binary_logloss: 0.370928
# [114]	valid_0's auc: 0.738052	valid_0's binary_logloss: 0.370906
# [115]	valid_0's auc: 0.738088	valid_0's binary_logloss: 0.370879
# [116]	valid_0's auc: 0.738165	valid_0's binary_logloss: 0.370842
# [117]	valid_0's auc: 0.738195	valid_0's binary_logloss: 0.370813
# [118]	valid_0's auc: 0.738228	valid_0's binary_logloss: 0.370788
# [119]	valid_0's auc: 0.738266	valid_0's binary_logloss: 0.370761
# [120]	valid_0's auc: 0.738297	valid_0's binary_logloss: 0.370734
# [121]	valid_0's auc: 0.738357	valid_0's binary_logloss: 0.370707
# [122]	valid_0's auc: 0.738377	valid_0's binary_logloss: 0.370682
# [123]	valid_0's auc: 0.738403	valid_0's binary_logloss: 0.370668
# [124]	valid_0's auc: 0.738449	valid_0's binary_logloss: 0.370645
# [125]	valid_0's auc: 0.738473	valid_0's binary_logloss: 0.370621
# [126]	valid_0's auc: 0.738513	valid_0's binary_logloss: 0.370604
# [127]	valid_0's auc: 0.738576	valid_0's binary_logloss: 0.370578
# [128]	valid_0's auc: 0.73861	valid_0's binary_logloss: 0.370555
# [129]	valid_0's auc: 0.738644	valid_0's binary_logloss: 0.370536
# [130]	valid_0's auc: 0.73867	valid_0's binary_logloss: 0.37052
# [131]	valid_0's auc: 0.7387	valid_0's binary_logloss: 0.370503
# [132]	valid_0's auc: 0.738741	valid_0's binary_logloss: 0.370486
# [133]	valid_0's auc: 0.738773	valid_0's binary_logloss: 0.370465
# [134]	valid_0's auc: 0.738789	valid_0's binary_logloss: 0.370452
# [135]	valid_0's auc: 0.738847	valid_0's binary_logloss: 0.370436
# [136]	valid_0's auc: 0.738856	valid_0's binary_logloss: 0.370421
# [137]	valid_0's auc: 0.738874	valid_0's binary_logloss: 0.37041
# [138]	valid_0's auc: 0.738893	valid_0's binary_logloss: 0.370402
# [139]	valid_0's auc: 0.73894	valid_0's binary_logloss: 0.370374
# [140]	valid_0's auc: 0.738976	valid_0's binary_logloss: 0.370362
# [141]	valid_0's auc: 0.739004	valid_0's binary_logloss: 0.370341
# [142]	valid_0's auc: 0.739021	valid_0's binary_logloss: 0.370329
# [143]	valid_0's auc: 0.73905	valid_0's binary_logloss: 0.370303
# [144]	valid_0's auc: 0.739069	valid_0's binary_logloss: 0.370289
# [145]	valid_0's auc: 0.739109	valid_0's binary_logloss: 0.370276
# [146]	valid_0's auc: 0.739133	valid_0's binary_logloss: 0.370259
# [147]	valid_0's auc: 0.73914	valid_0's binary_logloss: 0.370253
# [148]	valid_0's auc: 0.739171	valid_0's binary_logloss: 0.370243
# [149]	valid_0's auc: 0.739179	valid_0's binary_logloss: 0.370239
# [150]	valid_0's auc: 0.73923	valid_0's binary_logloss: 0.370221
# [151]	valid_0's auc: 0.73923	valid_0's binary_logloss: 0.370216
# [152]	valid_0's auc: 0.739253	valid_0's binary_logloss: 0.3702
# [153]	valid_0's auc: 0.739281	valid_0's binary_logloss: 0.37018
# [154]	valid_0's auc: 0.739311	valid_0's binary_logloss: 0.370165
# [155]	valid_0's auc: 0.739371	valid_0's binary_logloss: 0.370138
# [156]	valid_0's auc: 0.739379	valid_0's binary_logloss: 0.370129
# [157]	valid_0's auc: 0.739399	valid_0's binary_logloss: 0.370119
# [158]	valid_0's auc: 0.739413	valid_0's binary_logloss: 0.370116
# [159]	valid_0's auc: 0.739449	valid_0's binary_logloss: 0.370104
# [160]	valid_0's auc: 0.739452	valid_0's binary_logloss: 0.370104
# [161]	valid_0's auc: 0.739475	valid_0's binary_logloss: 0.370087
# [162]	valid_0's auc: 0.739491	valid_0's binary_logloss: 0.370076
# [163]	valid_0's auc: 0.739493	valid_0's binary_logloss: 0.370072
# [164]	valid_0's auc: 0.739493	valid_0's binary_logloss: 0.370073
# [165]	valid_0's auc: 0.739505	valid_0's binary_logloss: 0.370061
# [166]	valid_0's auc: 0.739517	valid_0's binary_logloss: 0.370051
# [167]	valid_0's auc: 0.739534	valid_0's binary_logloss: 0.370033
# [168]	valid_0's auc: 0.739542	valid_0's binary_logloss: 0.370034
# [169]	valid_0's auc: 0.739543	valid_0's binary_logloss: 0.370025
# [170]	valid_0's auc: 0.73958	valid_0's binary_logloss: 0.370013
# [171]	valid_0's auc: 0.739583	valid_0's binary_logloss: 0.37001
# [172]	valid_0's auc: 0.739579	valid_0's binary_logloss: 0.370008
# [173]	valid_0's auc: 0.739611	valid_0's binary_logloss: 0.369996
# [174]	valid_0's auc: 0.739624	valid_0's binary_logloss: 0.369986
# [175]	valid_0's auc: 0.739628	valid_0's binary_logloss: 0.36998
# [176]	valid_0's auc: 0.739629	valid_0's binary_logloss: 0.36998
# [177]	valid_0's auc: 0.739643	valid_0's binary_logloss: 0.36997
# [178]	valid_0's auc: 0.739653	valid_0's binary_logloss: 0.369961
# [179]	valid_0's auc: 0.739652	valid_0's binary_logloss: 0.369961
# [180]	valid_0's auc: 0.739661	valid_0's binary_logloss: 0.369961
# [181]	valid_0's auc: 0.739693	valid_0's binary_logloss: 0.36995
# [182]	valid_0's auc: 0.739732	valid_0's binary_logloss: 0.369932
# [183]	valid_0's auc: 0.73974	valid_0's binary_logloss: 0.369927
# [184]	valid_0's auc: 0.739733	valid_0's binary_logloss: 0.369929
# [185]	valid_0's auc: 0.739766	valid_0's binary_logloss: 0.369913
# [186]	valid_0's auc: 0.739763	valid_0's binary_logloss: 0.369914
# [187]	valid_0's auc: 0.73979	valid_0's binary_logloss: 0.369891
# [188]	valid_0's auc: 0.7398	valid_0's binary_logloss: 0.369889
# [189]	valid_0's auc: 0.739795	valid_0's binary_logloss: 0.369887
# [190]	valid_0's auc: 0.7398	valid_0's binary_logloss: 0.36988
# [191]	valid_0's auc: 0.739812	valid_0's binary_logloss: 0.369865
# [192]	valid_0's auc: 0.73981	valid_0's binary_logloss: 0.369862
# [193]	valid_0's auc: 0.739824	valid_0's binary_logloss: 0.36986
# [194]	valid_0's auc: 0.739836	valid_0's binary_logloss: 0.369857
# [195]	valid_0's auc: 0.73985	valid_0's binary_logloss: 0.369852
# [196]	valid_0's auc: 0.73986	valid_0's binary_logloss: 0.369843
# [197]	valid_0's auc: 0.739892	valid_0's binary_logloss: 0.369831
# [198]	valid_0's auc: 0.739903	valid_0's binary_logloss: 0.369827
# [199]	valid_0's auc: 0.739904	valid_0's binary_logloss: 0.369825
# [200]	valid_0's auc: 0.739953	valid_0's binary_logloss: 0.369803
# [201]	valid_0's auc: 0.739964	valid_0's binary_logloss: 0.369791
# [202]	valid_0's auc: 0.739961	valid_0's binary_logloss: 0.369792
# [203]	valid_0's auc: 0.739963	valid_0's binary_logloss: 0.369793
# [204]	valid_0's auc: 0.739975	valid_0's binary_logloss: 0.369783
# [205]	valid_0's auc: 0.739989	valid_0's binary_logloss: 0.369778
# [206]	valid_0's auc: 0.739988	valid_0's binary_logloss: 0.369775
# [207]	valid_0's auc: 0.739992	valid_0's binary_logloss: 0.369771
# [208]	valid_0's auc: 0.739999	valid_0's binary_logloss: 0.369768
# [209]	valid_0's auc: 0.74003	valid_0's binary_logloss: 0.36976
# [210]	valid_0's auc: 0.740046	valid_0's binary_logloss: 0.369752
# [211]	valid_0's auc: 0.740041	valid_0's binary_logloss: 0.369753
# [212]	valid_0's auc: 0.740046	valid_0's binary_logloss: 0.369753
# [213]	valid_0's auc: 0.740064	valid_0's binary_logloss: 0.369748
# [214]	valid_0's auc: 0.740063	valid_0's binary_logloss: 0.369745
# [215]	valid_0's auc: 0.740069	valid_0's binary_logloss: 0.369733
# [216]	valid_0's auc: 0.740071	valid_0's binary_logloss: 0.369733
# [217]	valid_0's auc: 0.740066	valid_0's binary_logloss: 0.369734
# [218]	valid_0's auc: 0.740062	valid_0's binary_logloss: 0.369732
# [219]	valid_0's auc: 0.740062	valid_0's binary_logloss: 0.369733
# [220]	valid_0's auc: 0.740077	valid_0's binary_logloss: 0.369727
# [221]	valid_0's auc: 0.740109	valid_0's binary_logloss: 0.369718
# [222]	valid_0's auc: 0.740109	valid_0's binary_logloss: 0.369721
# [223]	valid_0's auc: 0.740128	valid_0's binary_logloss: 0.369718
# [224]	valid_0's auc: 0.740138	valid_0's binary_logloss: 0.369709
# [225]	valid_0's auc: 0.74015	valid_0's binary_logloss: 0.369705
# [226]	valid_0's auc: 0.740166	valid_0's binary_logloss: 0.3697
# [227]	valid_0's auc: 0.740167	valid_0's binary_logloss: 0.369698
# [228]	valid_0's auc: 0.740167	valid_0's binary_logloss: 0.369697
# [229]	valid_0's auc: 0.740183	valid_0's binary_logloss: 0.369689
# [230]	valid_0's auc: 0.740185	valid_0's binary_logloss: 0.369685
# [231]	valid_0's auc: 0.740183	valid_0's binary_logloss: 0.369686
# [232]	valid_0's auc: 0.740179	valid_0's binary_logloss: 0.369687
# [233]	valid_0's auc: 0.740188	valid_0's binary_logloss: 0.369685
# [234]	valid_0's auc: 0.74018	valid_0's binary_logloss: 0.369688
# [235]	valid_0's auc: 0.740189	valid_0's binary_logloss: 0.369683
# [236]	valid_0's auc: 0.740201	valid_0's binary_logloss: 0.369681
# [237]	valid_0's auc: 0.740192	valid_0's binary_logloss: 0.369682
# [238]	valid_0's auc: 0.740201	valid_0's binary_logloss: 0.369679
# [239]	valid_0's auc: 0.740208	valid_0's binary_logloss: 0.369674
# [240]	valid_0's auc: 0.740207	valid_0's binary_logloss: 0.369674
# [241]	valid_0's auc: 0.74023	valid_0's binary_logloss: 0.369664
# [242]	valid_0's auc: 0.740231	valid_0's binary_logloss: 0.369662
# [243]	valid_0's auc: 0.740227	valid_0's binary_logloss: 0.369664
# [244]	valid_0's auc: 0.740243	valid_0's binary_logloss: 0.36966
# [245]	valid_0's auc: 0.740237	valid_0's binary_logloss: 0.369664
# [246]	valid_0's auc: 0.74024	valid_0's binary_logloss: 0.36966
# [247]	valid_0's auc: 0.740238	valid_0's binary_logloss: 0.369661
# [248]	valid_0's auc: 0.74024	valid_0's binary_logloss: 0.369658
# [249]	valid_0's auc: 0.740238	valid_0's binary_logloss: 0.369657
# [250]	valid_0's auc: 0.740239	valid_0's binary_logloss: 0.369654
# [251]	valid_0's auc: 0.740236	valid_0's binary_logloss: 0.369655
# [252]	valid_0's auc: 0.740238	valid_0's binary_logloss: 0.369655
# [253]	valid_0's auc: 0.740245	valid_0's binary_logloss: 0.369649
# [254]	valid_0's auc: 0.740248	valid_0's binary_logloss: 0.369647
# [255]	valid_0's auc: 0.74026	valid_0's binary_logloss: 0.369643
# [256]	valid_0's auc: 0.740259	valid_0's binary_logloss: 0.369643
# [257]	valid_0's auc: 0.740318	valid_0's binary_logloss: 0.369622
# [258]	valid_0's auc: 0.740323	valid_0's binary_logloss: 0.369623
# [259]	valid_0's auc: 0.74033	valid_0's binary_logloss: 0.369619
# [260]	valid_0's auc: 0.74034	valid_0's binary_logloss: 0.369616
# [261]	valid_0's auc: 0.740343	valid_0's binary_logloss: 0.369613
# [262]	valid_0's auc: 0.740338	valid_0's binary_logloss: 0.369613
# [263]	valid_0's auc: 0.740335	valid_0's binary_logloss: 0.369613
# [264]	valid_0's auc: 0.740341	valid_0's binary_logloss: 0.369609
# [265]	valid_0's auc: 0.740339	valid_0's binary_logloss: 0.369609
# [266]	valid_0's auc: 0.740343	valid_0's binary_logloss: 0.369606
# [267]	valid_0's auc: 0.740338	valid_0's binary_logloss: 0.369608
# [268]	valid_0's auc: 0.740341	valid_0's binary_logloss: 0.369607
# [269]	valid_0's auc: 0.740345	valid_0's binary_logloss: 0.369604
# [270]	valid_0's auc: 0.740351	valid_0's binary_logloss: 0.3696
# [271]	valid_0's auc: 0.740361	valid_0's binary_logloss: 0.369594
# [272]	valid_0's auc: 0.740362	valid_0's binary_logloss: 0.369593
# [273]	valid_0's auc: 0.740361	valid_0's binary_logloss: 0.369594
# [274]	valid_0's auc: 0.74039	valid_0's binary_logloss: 0.369583
# [275]	valid_0's auc: 0.740396	valid_0's binary_logloss: 0.36958
# [276]	valid_0's auc: 0.740402	valid_0's binary_logloss: 0.369578
# [277]	valid_0's auc: 0.740405	valid_0's binary_logloss: 0.369577
# [278]	valid_0's auc: 0.740434	valid_0's binary_logloss: 0.369562
# [279]	valid_0's auc: 0.740426	valid_0's binary_logloss: 0.369562
# [280]	valid_0's auc: 0.740421	valid_0's binary_logloss: 0.369564
# [281]	valid_0's auc: 0.740424	valid_0's binary_logloss: 0.369561
# [282]	valid_0's auc: 0.740418	valid_0's binary_logloss: 0.369564
# [283]	valid_0's auc: 0.740427	valid_0's binary_logloss: 0.369563
# [284]	valid_0's auc: 0.740446	valid_0's binary_logloss: 0.369554
# [285]	valid_0's auc: 0.740442	valid_0's binary_logloss: 0.369557
# [286]	valid_0's auc: 0.740454	valid_0's binary_logloss: 0.369552
# [287]	valid_0's auc: 0.740451	valid_0's binary_logloss: 0.369553
# [288]	valid_0's auc: 0.740453	valid_0's binary_logloss: 0.369553
# [289]	valid_0's auc: 0.740455	valid_0's binary_logloss: 0.36955
# [290]	valid_0's auc: 0.740458	valid_0's binary_logloss: 0.36955
# [291]	valid_0's auc: 0.740465	valid_0's binary_logloss: 0.369549
# [292]	valid_0's auc: 0.740462	valid_0's binary_logloss: 0.369551
# [293]	valid_0's auc: 0.740475	valid_0's binary_logloss: 0.36954
# [294]	valid_0's auc: 0.74048	valid_0's binary_logloss: 0.369537
# [295]	valid_0's auc: 0.740482	valid_0's binary_logloss: 0.369534
# [296]	valid_0's auc: 0.740472	valid_0's binary_logloss: 0.369537
# [297]	valid_0's auc: 0.740471	valid_0's binary_logloss: 0.369538
# [298]	valid_0's auc: 0.740478	valid_0's binary_logloss: 0.369537
# [299]	valid_0's auc: 0.740478	valid_0's binary_logloss: 0.369537
# [300]	valid_0's auc: 0.740479	valid_0's binary_logloss: 0.369536
# [301]	valid_0's auc: 0.74048	valid_0's binary_logloss: 0.369533
# [302]	valid_0's auc: 0.74048	valid_0's binary_logloss: 0.369534
# [303]	valid_0's auc: 0.740476	valid_0's binary_logloss: 0.369536
# [304]	valid_0's auc: 0.740481	valid_0's binary_logloss: 0.369533
# [305]	valid_0's auc: 0.740489	valid_0's binary_logloss: 0.36953
# [306]	valid_0's auc: 0.740493	valid_0's binary_logloss: 0.36953
# [307]	valid_0's auc: 0.740492	valid_0's binary_logloss: 0.36953
# [308]	valid_0's auc: 0.740496	valid_0's binary_logloss: 0.369529
# [309]	valid_0's auc: 0.740497	valid_0's binary_logloss: 0.369528
# [310]	valid_0's auc: 0.740494	valid_0's binary_logloss: 0.36953
# [311]	valid_0's auc: 0.740491	valid_0's binary_logloss: 0.369528
# [312]	valid_0's auc: 0.740494	valid_0's binary_logloss: 0.369525
# [313]	valid_0's auc: 0.740485	valid_0's binary_logloss: 0.369525
# [314]	valid_0's auc: 0.740495	valid_0's binary_logloss: 0.369518
# [315]	valid_0's auc: 0.740498	valid_0's binary_logloss: 0.369517
# [316]	valid_0's auc: 0.740501	valid_0's binary_logloss: 0.369516
# [317]	valid_0's auc: 0.740506	valid_0's binary_logloss: 0.369505
# [318]	valid_0's auc: 0.740506	valid_0's binary_logloss: 0.369501
# [319]	valid_0's auc: 0.740508	valid_0's binary_logloss: 0.369501
# [320]	valid_0's auc: 0.740512	valid_0's binary_logloss: 0.369501
# [321]	valid_0's auc: 0.740517	valid_0's binary_logloss: 0.3695
# [322]	valid_0's auc: 0.740521	valid_0's binary_logloss: 0.369497
# [323]	valid_0's auc: 0.740525	valid_0's binary_logloss: 0.369496
# [324]	valid_0's auc: 0.740524	valid_0's binary_logloss: 0.369497
# [325]	valid_0's auc: 0.740528	valid_0's binary_logloss: 0.369495
# [326]	valid_0's auc: 0.740527	valid_0's binary_logloss: 0.369497
# [327]	valid_0's auc: 0.740524	valid_0's binary_logloss: 0.369498
# [328]	valid_0's auc: 0.740521	valid_0's binary_logloss: 0.369499
# [329]	valid_0's auc: 0.740527	valid_0's binary_logloss: 0.369496
# [330]	valid_0's auc: 0.740532	valid_0's binary_logloss: 0.369492
# [331]	valid_0's auc: 0.740533	valid_0's binary_logloss: 0.369491
# [332]	valid_0's auc: 0.74053	valid_0's binary_logloss: 0.36949
# [333]	valid_0's auc: 0.740524	valid_0's binary_logloss: 0.369491
# [334]	valid_0's auc: 0.740525	valid_0's binary_logloss: 0.369491
# [335]	valid_0's auc: 0.740526	valid_0's binary_logloss: 0.36949
# [336]	valid_0's auc: 0.740531	valid_0's binary_logloss: 0.36949
# [337]	valid_0's auc: 0.740548	valid_0's binary_logloss: 0.369479
# [338]	valid_0's auc: 0.740556	valid_0's binary_logloss: 0.369473
# [339]	valid_0's auc: 0.740554	valid_0's binary_logloss: 0.369474
# [340]	valid_0's auc: 0.740556	valid_0's binary_logloss: 0.369473
# [341]	valid_0's auc: 0.740552	valid_0's binary_logloss: 0.369475
# [342]	valid_0's auc: 0.740556	valid_0's binary_logloss: 0.369473
# [343]	valid_0's auc: 0.740557	valid_0's binary_logloss: 0.369473
# [344]	valid_0's auc: 0.740561	valid_0's binary_logloss: 0.36947
# [345]	valid_0's auc: 0.740564	valid_0's binary_logloss: 0.369466
# [346]	valid_0's auc: 0.740566	valid_0's binary_logloss: 0.369466
# [347]	valid_0's auc: 0.740566	valid_0's binary_logloss: 0.369465
# [348]	valid_0's auc: 0.74056	valid_0's binary_logloss: 0.369466
# [349]	valid_0's auc: 0.740558	valid_0's binary_logloss: 0.369466
# [350]	valid_0's auc: 0.740558	valid_0's binary_logloss: 0.369467
# [351]	valid_0's auc: 0.740554	valid_0's binary_logloss: 0.369468
# [352]	valid_0's auc: 0.740551	valid_0's binary_logloss: 0.369469
# [353]	valid_0's auc: 0.740552	valid_0's binary_logloss: 0.369469
# [354]	valid_0's auc: 0.740555	valid_0's binary_logloss: 0.369466
# [355]	valid_0's auc: 0.740554	valid_0's binary_logloss: 0.369464
# [356]	valid_0's auc: 0.740552	valid_0's binary_logloss: 0.369463
# [357]	valid_0's auc: 0.740557	valid_0's binary_logloss: 0.369463
# [358]	valid_0's auc: 0.740544	valid_0's binary_logloss: 0.369465
# [359]	valid_0's auc: 0.740542	valid_0's binary_logloss: 0.369467
# [360]	valid_0's auc: 0.74054	valid_0's binary_logloss: 0.369467
# [361]	valid_0's auc: 0.740542	valid_0's binary_logloss: 0.369467
# [362]	valid_0's auc: 0.740544	valid_0's binary_logloss: 0.369463
# [363]	valid_0's auc: 0.740532	valid_0's binary_logloss: 0.369465
# [364]	valid_0's auc: 0.740525	valid_0's binary_logloss: 0.369468
# [365]	valid_0's auc: 0.740527	valid_0's binary_logloss: 0.369465
# [366]	valid_0's auc: 0.740526	valid_0's binary_logloss: 0.369464
# [367]	valid_0's auc: 0.740529	valid_0's binary_logloss: 0.369464
# [368]	valid_0's auc: 0.74053	valid_0's binary_logloss: 0.369463
# [369]	valid_0's auc: 0.740529	valid_0's binary_logloss: 0.369464
# [370]	valid_0's auc: 0.740533	valid_0's binary_logloss: 0.369463
# [371]	valid_0's auc: 0.740538	valid_0's binary_logloss: 0.369462
# [372]	valid_0's auc: 0.740541	valid_0's binary_logloss: 0.36946
# [373]	valid_0's auc: 0.740539	valid_0's binary_logloss: 0.369462
# [374]	valid_0's auc: 0.74054	valid_0's binary_logloss: 0.36946
# [375]	valid_0's auc: 0.740555	valid_0's binary_logloss: 0.369452
# [376]	valid_0's auc: 0.740555	valid_0's binary_logloss: 0.369454
# [377]	valid_0's auc: 0.740561	valid_0's binary_logloss: 0.369452
# [378]	valid_0's auc: 0.740562	valid_0's binary_logloss: 0.369451
# [379]	valid_0's auc: 0.740549	valid_0's binary_logloss: 0.369454
# [380]	valid_0's auc: 0.740555	valid_0's binary_logloss: 0.369453
# [381]	valid_0's auc: 0.740555	valid_0's binary_logloss: 0.369452
# [382]	valid_0's auc: 0.740556	valid_0's binary_logloss: 0.369451
# [383]	valid_0's auc: 0.740553	valid_0's binary_logloss: 0.369453
# [384]	valid_0's auc: 0.740553	valid_0's binary_logloss: 0.369451
# [385]	valid_0's auc: 0.740562	valid_0's binary_logloss: 0.369448
# [386]	valid_0's auc: 0.740573	valid_0's binary_logloss: 0.369442
# [387]	valid_0's auc: 0.740572	valid_0's binary_logloss: 0.369439
# [388]	valid_0's auc: 0.740574	valid_0's binary_logloss: 0.36944
# [389]	valid_0's auc: 0.740566	valid_0's binary_logloss: 0.369441
# [390]	valid_0's auc: 0.74057	valid_0's binary_logloss: 0.369439
# [391]	valid_0's auc: 0.74057	valid_0's binary_logloss: 0.369438
# [392]	valid_0's auc: 0.74057	valid_0's binary_logloss: 0.369438
# [393]	valid_0's auc: 0.740566	valid_0's binary_logloss: 0.369437
# [394]	valid_0's auc: 0.740562	valid_0's binary_logloss: 0.369439
# [395]	valid_0's auc: 0.740569	valid_0's binary_logloss: 0.369435
# [396]	valid_0's auc: 0.740577	valid_0's binary_logloss: 0.36943
# [397]	valid_0's auc: 0.740579	valid_0's binary_logloss: 0.369429
# [398]	valid_0's auc: 0.740581	valid_0's binary_logloss: 0.369428
# [399]	valid_0's auc: 0.740584	valid_0's binary_logloss: 0.369426
# [400]	valid_0's auc: 0.740591	valid_0's binary_logloss: 0.369424
# [401]	valid_0's auc: 0.740582	valid_0's binary_logloss: 0.369425
# [402]	valid_0's auc: 0.740583	valid_0's binary_logloss: 0.369424
# [403]	valid_0's auc: 0.740584	valid_0's binary_logloss: 0.369424
# [404]	valid_0's auc: 0.740586	valid_0's binary_logloss: 0.36942
# [405]	valid_0's auc: 0.74059	valid_0's binary_logloss: 0.36942
# [406]	valid_0's auc: 0.740588	valid_0's binary_logloss: 0.369419
# [407]	valid_0's auc: 0.740586	valid_0's binary_logloss: 0.369419
# [408]	valid_0's auc: 0.740584	valid_0's binary_logloss: 0.36942
# [409]	valid_0's auc: 0.740588	valid_0's binary_logloss: 0.369419
# [410]	valid_0's auc: 0.740591	valid_0's binary_logloss: 0.369416
# [411]	valid_0's auc: 0.740592	valid_0's binary_logloss: 0.369414
# [412]	valid_0's auc: 0.740597	valid_0's binary_logloss: 0.369411
# [413]	valid_0's auc: 0.740599	valid_0's binary_logloss: 0.36941
# [414]	valid_0's auc: 0.740598	valid_0's binary_logloss: 0.369409
# [415]	valid_0's auc: 0.7406	valid_0's binary_logloss: 0.369406
# [416]	valid_0's auc: 0.740594	valid_0's binary_logloss: 0.369408
# [417]	valid_0's auc: 0.740604	valid_0's binary_logloss: 0.369403
# [418]	valid_0's auc: 0.7406	valid_0's binary_logloss: 0.369406
# [419]	valid_0's auc: 0.740607	valid_0's binary_logloss: 0.369404
# [420]	valid_0's auc: 0.740612	valid_0's binary_logloss: 0.369404
# [421]	valid_0's auc: 0.740603	valid_0's binary_logloss: 0.369404
# [422]	valid_0's auc: 0.740601	valid_0's binary_logloss: 0.369406
# [423]	valid_0's auc: 0.740605	valid_0's binary_logloss: 0.369407
# [424]	valid_0's auc: 0.740608	valid_0's binary_logloss: 0.369406
# [425]	valid_0's auc: 0.740603	valid_0's binary_logloss: 0.369406
# [426]	valid_0's auc: 0.740607	valid_0's binary_logloss: 0.369402
# [427]	valid_0's auc: 0.740601	valid_0's binary_logloss: 0.369405
# [428]	valid_0's auc: 0.740603	valid_0's binary_logloss: 0.369404
# [429]	valid_0's auc: 0.740603	valid_0's binary_logloss: 0.369406
# [430]	valid_0's auc: 0.740607	valid_0's binary_logloss: 0.369401
# [431]	valid_0's auc: 0.740609	valid_0's binary_logloss: 0.369402
# [432]	valid_0's auc: 0.740616	valid_0's binary_logloss: 0.3694
# [433]	valid_0's auc: 0.740623	valid_0's binary_logloss: 0.369398
# [434]	valid_0's auc: 0.740619	valid_0's binary_logloss: 0.369398
# [435]	valid_0's auc: 0.74062	valid_0's binary_logloss: 0.369399
# [436]	valid_0's auc: 0.740612	valid_0's binary_logloss: 0.369402
# [437]	valid_0's auc: 0.740615	valid_0's binary_logloss: 0.369401
# [438]	valid_0's auc: 0.740612	valid_0's binary_logloss: 0.369403
# [439]	valid_0's auc: 0.740615	valid_0's binary_logloss: 0.3694
# [440]	valid_0's auc: 0.740613	valid_0's binary_logloss: 0.369402
# [441]	valid_0's auc: 0.740616	valid_0's binary_logloss: 0.3694
# [442]	valid_0's auc: 0.74061	valid_0's binary_logloss: 0.369399
# [443]	valid_0's auc: 0.74061	valid_0's binary_logloss: 0.369396
# [444]	valid_0's auc: 0.740617	valid_0's binary_logloss: 0.369386
# [445]	valid_0's auc: 0.740617	valid_0's binary_logloss: 0.369387
# [446]	valid_0's auc: 0.740616	valid_0's binary_logloss: 0.369387
# [447]	valid_0's auc: 0.740612	valid_0's binary_logloss: 0.369388
# [448]	valid_0's auc: 0.740607	valid_0's binary_logloss: 0.369391
# [449]	valid_0's auc: 0.740609	valid_0's binary_logloss: 0.369391
# [450]	valid_0's auc: 0.740616	valid_0's binary_logloss: 0.369389
# [451]	valid_0's auc: 0.740615	valid_0's binary_logloss: 0.369391
# [452]	valid_0's auc: 0.740614	valid_0's binary_logloss: 0.36939
# [453]	valid_0's auc: 0.740619	valid_0's binary_logloss: 0.369385
# [454]	valid_0's auc: 0.740624	valid_0's binary_logloss: 0.369384
# [455]	valid_0's auc: 0.740622	valid_0's binary_logloss: 0.369382
# [456]	valid_0's auc: 0.740623	valid_0's binary_logloss: 0.369381
# [457]	valid_0's auc: 0.740629	valid_0's binary_logloss: 0.369373
# [458]	valid_0's auc: 0.740628	valid_0's binary_logloss: 0.369371
# [459]	valid_0's auc: 0.74063	valid_0's binary_logloss: 0.369371
# [460]	valid_0's auc: 0.74062	valid_0's binary_logloss: 0.369375
# [461]	valid_0's auc: 0.74062	valid_0's binary_logloss: 0.369376
# [462]	valid_0's auc: 0.740631	valid_0's binary_logloss: 0.369373
# [463]	valid_0's auc: 0.740635	valid_0's binary_logloss: 0.369373
# [464]	valid_0's auc: 0.74063	valid_0's binary_logloss: 0.369374
# [465]	valid_0's auc: 0.74063	valid_0's binary_logloss: 0.369376
# [466]	valid_0's auc: 0.740635	valid_0's binary_logloss: 0.369375
# [467]	valid_0's auc: 0.740643	valid_0's binary_logloss: 0.369372
# [468]	valid_0's auc: 0.740638	valid_0's binary_logloss: 0.369373
# [469]	valid_0's auc: 0.740641	valid_0's binary_logloss: 0.369372
# [470]	valid_0's auc: 0.740642	valid_0's binary_logloss: 0.369374
# [471]	valid_0's auc: 0.740636	valid_0's binary_logloss: 0.369374
# [472]	valid_0's auc: 0.740644	valid_0's binary_logloss: 0.369364
# [473]	valid_0's auc: 0.740644	valid_0's binary_logloss: 0.36936
# [474]	valid_0's auc: 0.740646	valid_0's binary_logloss: 0.369359
# [475]	valid_0's auc: 0.740646	valid_0's binary_logloss: 0.369359
# [476]	valid_0's auc: 0.740643	valid_0's binary_logloss: 0.36936
# [477]	valid_0's auc: 0.740648	valid_0's binary_logloss: 0.369356
# [478]	valid_0's auc: 0.740655	valid_0's binary_logloss: 0.36935
# [479]	valid_0's auc: 0.740656	valid_0's binary_logloss: 0.36935
# [480]	valid_0's auc: 0.740657	valid_0's binary_logloss: 0.36935
# [481]	valid_0's auc: 0.740656	valid_0's binary_logloss: 0.36935
# [482]	valid_0's auc: 0.740645	valid_0's binary_logloss: 0.369352
# [483]	valid_0's auc: 0.740638	valid_0's binary_logloss: 0.369355
# [484]	valid_0's auc: 0.740641	valid_0's binary_logloss: 0.369353
# [485]	valid_0's auc: 0.740646	valid_0's binary_logloss: 0.369352
# [486]	valid_0's auc: 0.74065	valid_0's binary_logloss: 0.369344
# [487]	valid_0's auc: 0.740647	valid_0's binary_logloss: 0.369345
# [488]	valid_0's auc: 0.740645	valid_0's binary_logloss: 0.369344
# [489]	valid_0's auc: 0.740646	valid_0's binary_logloss: 0.369343
# [490]	valid_0's auc: 0.740659	valid_0's binary_logloss: 0.369341
# [491]	valid_0's auc: 0.740669	valid_0's binary_logloss: 0.369339
# [492]	valid_0's auc: 0.740679	valid_0's binary_logloss: 0.369335
# [493]	valid_0's auc: 0.740677	valid_0's binary_logloss: 0.369335
# [494]	valid_0's auc: 0.740679	valid_0's binary_logloss: 0.369334
# [495]	valid_0's auc: 0.740679	valid_0's binary_logloss: 0.369335
# [496]	valid_0's auc: 0.740677	valid_0's binary_logloss: 0.369334
# [497]	valid_0's auc: 0.740672	valid_0's binary_logloss: 0.369336
# [498]	valid_0's auc: 0.740672	valid_0's binary_logloss: 0.369337
# [499]	valid_0's auc: 0.740672	valid_0's binary_logloss: 0.369336
# [500]	valid_0's auc: 0.740676	valid_0's binary_logloss: 0.369333
# [501]	valid_0's auc: 0.740677	valid_0's binary_logloss: 0.369331
# [502]	valid_0's auc: 0.740686	valid_0's binary_logloss: 0.369321
# [503]	valid_0's auc: 0.740692	valid_0's binary_logloss: 0.36932
# [504]	valid_0's auc: 0.740692	valid_0's binary_logloss: 0.369319
# [505]	valid_0's auc: 0.740719	valid_0's binary_logloss: 0.369312
# [506]	valid_0's auc: 0.740732	valid_0's binary_logloss: 0.369308
# [507]	valid_0's auc: 0.740729	valid_0's binary_logloss: 0.36931
# [508]	valid_0's auc: 0.740728	valid_0's binary_logloss: 0.36931
# [509]	valid_0's auc: 0.74073	valid_0's binary_logloss: 0.369311
# [510]	valid_0's auc: 0.740734	valid_0's binary_logloss: 0.369303
# [511]	valid_0's auc: 0.740729	valid_0's binary_logloss: 0.369306
# [512]	valid_0's auc: 0.740729	valid_0's binary_logloss: 0.369306
# [513]	valid_0's auc: 0.740732	valid_0's binary_logloss: 0.369306
# [514]	valid_0's auc: 0.740733	valid_0's binary_logloss: 0.369306
# [515]	valid_0's auc: 0.740735	valid_0's binary_logloss: 0.369304
# [516]	valid_0's auc: 0.74074	valid_0's binary_logloss: 0.369303
# [517]	valid_0's auc: 0.740736	valid_0's binary_logloss: 0.369305
# [518]	valid_0's auc: 0.740735	valid_0's binary_logloss: 0.369305
# [519]	valid_0's auc: 0.740732	valid_0's binary_logloss: 0.369306
# [520]	valid_0's auc: 0.740728	valid_0's binary_logloss: 0.369307
# [521]	valid_0's auc: 0.740721	valid_0's binary_logloss: 0.369311
# [522]	valid_0's auc: 0.74072	valid_0's binary_logloss: 0.36931
# [523]	valid_0's auc: 0.740719	valid_0's binary_logloss: 0.369311
# [524]	valid_0's auc: 0.740724	valid_0's binary_logloss: 0.369309
# [525]	valid_0's auc: 0.740736	valid_0's binary_logloss: 0.3693
# [526]	valid_0's auc: 0.740726	valid_0's binary_logloss: 0.369303
# [527]	valid_0's auc: 0.740724	valid_0's binary_logloss: 0.369304
# [528]	valid_0's auc: 0.740724	valid_0's binary_logloss: 0.369306
# [529]	valid_0's auc: 0.740727	valid_0's binary_logloss: 0.369305
# [530]	valid_0's auc: 0.740727	valid_0's binary_logloss: 0.369305
# [531]	valid_0's auc: 0.740726	valid_0's binary_logloss: 0.369305
# [532]	valid_0's auc: 0.740727	valid_0's binary_logloss: 0.369304
# [533]	valid_0's auc: 0.740729	valid_0's binary_logloss: 0.369304
# [534]	valid_0's auc: 0.740734	valid_0's binary_logloss: 0.369299
# [535]	valid_0's auc: 0.740733	valid_0's binary_logloss: 0.3693
# [536]	valid_0's auc: 0.740733	valid_0's binary_logloss: 0.3693
# [537]	valid_0's auc: 0.74073	valid_0's binary_logloss: 0.369303
# [538]	valid_0's auc: 0.740726	valid_0's binary_logloss: 0.369305
# [539]	valid_0's auc: 0.74073	valid_0's binary_logloss: 0.369301
# [540]	valid_0's auc: 0.740741	valid_0's binary_logloss: 0.369299
# [541]	valid_0's auc: 0.740738	valid_0's binary_logloss: 0.3693
# [542]	valid_0's auc: 0.740743	valid_0's binary_logloss: 0.369299
# [543]	valid_0's auc: 0.740745	valid_0's binary_logloss: 0.369299
# [544]	valid_0's auc: 0.740742	valid_0's binary_logloss: 0.3693
# [545]	valid_0's auc: 0.740739	valid_0's binary_logloss: 0.3693
# [546]	valid_0's auc: 0.740739	valid_0's binary_logloss: 0.3693
# [547]	valid_0's auc: 0.740743	valid_0's binary_logloss: 0.369299
# [548]	valid_0's auc: 0.740745	valid_0's binary_logloss: 0.369297
# [549]	valid_0's auc: 0.740739	valid_0's binary_logloss: 0.369297
# [550]	valid_0's auc: 0.740734	valid_0's binary_logloss: 0.369301
# [551]	valid_0's auc: 0.740728	valid_0's binary_logloss: 0.369303
# [552]	valid_0's auc: 0.740741	valid_0's binary_logloss: 0.369293
# [553]	valid_0's auc: 0.74074	valid_0's binary_logloss: 0.369294
# [554]	valid_0's auc: 0.74074	valid_0's binary_logloss: 0.369293
# [555]	valid_0's auc: 0.740732	valid_0's binary_logloss: 0.369296
# [556]	valid_0's auc: 0.740733	valid_0's binary_logloss: 0.369296
# [557]	valid_0's auc: 0.740732	valid_0's binary_logloss: 0.369298
# [558]	valid_0's auc: 0.740746	valid_0's binary_logloss: 0.369292
# [559]	valid_0's auc: 0.740752	valid_0's binary_logloss: 0.369289
# [560]	valid_0's auc: 0.740757	valid_0's binary_logloss: 0.369288
# [561]	valid_0's auc: 0.740762	valid_0's binary_logloss: 0.369286
# [562]	valid_0's auc: 0.740772	valid_0's binary_logloss: 0.369283
# [563]	valid_0's auc: 0.740785	valid_0's binary_logloss: 0.369279
# [564]	valid_0's auc: 0.740783	valid_0's binary_logloss: 0.36928
# [565]	valid_0's auc: 0.740778	valid_0's binary_logloss: 0.369281
# [566]	valid_0's auc: 0.740778	valid_0's binary_logloss: 0.369281
# [567]	valid_0's auc: 0.740771	valid_0's binary_logloss: 0.369283
# [568]	valid_0's auc: 0.74077	valid_0's binary_logloss: 0.369284
# [569]	valid_0's auc: 0.740781	valid_0's binary_logloss: 0.369281
# [570]	valid_0's auc: 0.740781	valid_0's binary_logloss: 0.369281
# [571]	valid_0's auc: 0.740776	valid_0's binary_logloss: 0.369283
# [572]	valid_0's auc: 0.740774	valid_0's binary_logloss: 0.369282
# [573]	valid_0's auc: 0.74077	valid_0's binary_logloss: 0.369282
# [574]	valid_0's auc: 0.740771	valid_0's binary_logloss: 0.369282
# [575]	valid_0's auc: 0.740773	valid_0's binary_logloss: 0.369281
# [576]	valid_0's auc: 0.740772	valid_0's binary_logloss: 0.369279
# [577]	valid_0's auc: 0.740776	valid_0's binary_logloss: 0.369278
# [578]	valid_0's auc: 0.740786	valid_0's binary_logloss: 0.369275
# [579]	valid_0's auc: 0.740793	valid_0's binary_logloss: 0.369271
# [580]	valid_0's auc: 0.740785	valid_0's binary_logloss: 0.369274
# [581]	valid_0's auc: 0.740785	valid_0's binary_logloss: 0.369272
# [582]	valid_0's auc: 0.74078	valid_0's binary_logloss: 0.369273
# [583]	valid_0's auc: 0.740785	valid_0's binary_logloss: 0.369273
# [584]	valid_0's auc: 0.740798	valid_0's binary_logloss: 0.369265
# [585]	valid_0's auc: 0.740798	valid_0's binary_logloss: 0.369263
# [586]	valid_0's auc: 0.740799	valid_0's binary_logloss: 0.369265
# [587]	valid_0's auc: 0.740799	valid_0's binary_logloss: 0.369265
# [588]	valid_0's auc: 0.740791	valid_0's binary_logloss: 0.369267
# [589]	valid_0's auc: 0.740791	valid_0's binary_logloss: 0.369267
# [590]	valid_0's auc: 0.740792	valid_0's binary_logloss: 0.369268
# [591]	valid_0's auc: 0.740785	valid_0's binary_logloss: 0.369271
# [592]	valid_0's auc: 0.740784	valid_0's binary_logloss: 0.36927
# [593]	valid_0's auc: 0.740788	valid_0's binary_logloss: 0.369267
# [594]	valid_0's auc: 0.74079	valid_0's binary_logloss: 0.369263
# [595]	valid_0's auc: 0.740794	valid_0's binary_logloss: 0.369262
# [596]	valid_0's auc: 0.740796	valid_0's binary_logloss: 0.36926
# [597]	valid_0's auc: 0.740789	valid_0's binary_logloss: 0.36926
# [598]	valid_0's auc: 0.740786	valid_0's binary_logloss: 0.369261
# [599]	valid_0's auc: 0.740778	valid_0's binary_logloss: 0.369265
# [600]	valid_0's auc: 0.740774	valid_0's binary_logloss: 0.369264
# [601]	valid_0's auc: 0.740773	valid_0's binary_logloss: 0.369264
# [602]	valid_0's auc: 0.740775	valid_0's binary_logloss: 0.369263
# [603]	valid_0's auc: 0.740768	valid_0's binary_logloss: 0.369265
# [604]	valid_0's auc: 0.740742	valid_0's binary_logloss: 0.369276
# [605]	valid_0's auc: 0.740736	valid_0's binary_logloss: 0.369278
# [606]	valid_0's auc: 0.740737	valid_0's binary_logloss: 0.369275
# [607]	valid_0's auc: 0.740738	valid_0's binary_logloss: 0.369274
# [608]	valid_0's auc: 0.740743	valid_0's binary_logloss: 0.36927
# [609]	valid_0's auc: 0.740731	valid_0's binary_logloss: 0.369273
# [610]	valid_0's auc: 0.740733	valid_0's binary_logloss: 0.369274
# [611]	valid_0's auc: 0.740735	valid_0's binary_logloss: 0.369272
# [612]	valid_0's auc: 0.740736	valid_0's binary_logloss: 0.36927
# [613]	valid_0's auc: 0.740725	valid_0's binary_logloss: 0.369273
# [614]	valid_0's auc: 0.740731	valid_0's binary_logloss: 0.36927
# [615]	valid_0's auc: 0.740736	valid_0's binary_logloss: 0.36926
# [616]	valid_0's auc: 0.74074	valid_0's binary_logloss: 0.369259
# [617]	valid_0's auc: 0.740739	valid_0's binary_logloss: 0.36926
# [618]	valid_0's auc: 0.74073	valid_0's binary_logloss: 0.369264
# [619]	valid_0's auc: 0.740729	valid_0's binary_logloss: 0.369263
# [620]	valid_0's auc: 0.74073	valid_0's binary_logloss: 0.369262
# [621]	valid_0's auc: 0.74074	valid_0's binary_logloss: 0.36926
# [622]	valid_0's auc: 0.740731	valid_0's binary_logloss: 0.369262
# [623]	valid_0's auc: 0.740742	valid_0's binary_logloss: 0.369259
# [624]	valid_0's auc: 0.740746	valid_0's binary_logloss: 0.369258
# [625]	valid_0's auc: 0.740741	valid_0's binary_logloss: 0.369261
# [626]	valid_0's auc: 0.740742	valid_0's binary_logloss: 0.369261
# [627]	valid_0's auc: 0.740746	valid_0's binary_logloss: 0.369255
# [628]	valid_0's auc: 0.740745	valid_0's binary_logloss: 0.369254
# [629]	valid_0's auc: 0.740736	valid_0's binary_logloss: 0.369255
# [630]	valid_0's auc: 0.740737	valid_0's binary_logloss: 0.369255
# [631]	valid_0's auc: 0.74074	valid_0's binary_logloss: 0.369248
# [632]	valid_0's auc: 0.740741	valid_0's binary_logloss: 0.369248
# [633]	valid_0's auc: 0.740744	valid_0's binary_logloss: 0.369245
# [634]	valid_0's auc: 0.740744	valid_0's binary_logloss: 0.369245
# [635]	valid_0's auc: 0.740745	valid_0's binary_logloss: 0.369245
# [636]	valid_0's auc: 0.740751	valid_0's binary_logloss: 0.369243
# [637]	valid_0's auc: 0.740761	valid_0's binary_logloss: 0.36924
# Early stopping, best iteration is:
# [587]	valid_0's auc: 0.740799	valid_0's binary_logloss: 0.369265
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.04, max_depth=20,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=1600, n_jobs=-1, num_leaves=63, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %% [markdown]
# ## Results

# %%
clf = LGBMClassifier(n_estimators=492, learning_rate=0.04, num_leaves=63, max_depth = 20)
clf.fit(
    data_train[feature_columns], data_train[target_column].values.ravel(),
    eval_metric='auc',
    verbose=True,
)

predictions = clf.predict_proba(data_test[feature_columns])

# %%
predictions[:, 1]
# Out:
# array([0.04484322, 0.07797082, 0.10175929, ..., 0.20971501, 0.32055829,
#        0.05838681])

# %%
prediction_df = pd.DataFrame(predictions[:, 1], columns=['target'])
prediction_df = prediction_df.reset_index()

# %%
prediction_df.to_csv('second_baseline.csv', index=0)
